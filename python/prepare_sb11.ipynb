# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/juanmalagon/Desktop/Malagon-Haelermans/phd_code/python'

# %%
os.chdir('/Users/juanmalagon/Desktop/Malagon-Haelermans/ftpdbicfes/4. Saber11/3. Resultados Saber11')

# %%
d20182 = pd.read_table('SB11_20182.TXT'
                       , sep='¬'
                       , encoding='utf-8'
                       , engine='python'
                      )

# %%
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-7d2da0a5d979> in <module>
# ----> 1 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
